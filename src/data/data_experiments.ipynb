# %%
import pandas as pd

# %%
raw_df = pd.read_csv('../../data/data_raw.csv')

# %%
raw_df.head()
# Out:
#            Name                                        Description
# 0      TeamSync  TeamSync aims to improve the quality and balan...
# 1  RandomCoffee  Random Coffee is a web-based service integrate...
# 2         EvOps  A self-hosted platform to share and discover l...
# 3    UrTraining  A web-based platform for creating, distributin...
# 4          Red7  An online version of the Russian game '7Red', ...

# %%
import nltk

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\harne\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\harne\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from data_preprocess import preprocess_text_for_BM25, build_bm25_index_from_df
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\harne\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\harne\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = preprocess_text_for_BM25(raw_df, text_col='Description')
bm25, docs, df = build_bm25_index_from_df(df)

# %%
docs[:1]
# Out:
# [['teamsync',
#   'aim',
#   'improve',
#   'quality',
#   'balance',
#   'student',
#   'team',
#   'offering',
#   'experience',
#   'discovering',
#   'evaluating',
#   'matching',
#   'potential',
#   'teammate']]

# %%
from data_preprocess import preprocess_text

stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

query = "AI game russian"

query = preprocess_text(query, stop_words, lemmatizer)

bm25.get_top_n(query, docs, n=5)
# Out:
# [['online',
#   'version',
#   'russian',
#   'game',
#   'featuring',
#   'secure',
#   'authentication',
#   'multiple',
#   'game',
#   'mode',
#   'player',
#   'statistic',
#   'achievement'],
#  ['platform',
#   'creating',
#   'testing',
#   'sharing',
#   'educational',
#   'game',
#   'ai',
#   'support'],
#  ['educational',
#   'platform',
#   'teaching',
#   'game',
#   'development',
#   'project',
#   'ai',
#   'guidance'],
#  ['platform', 'collaborative', 'game', 'development', 'design', 'testing'],
#  ['game', 'featuring', 'unique', 'mechanic', 'visual', 'style']]

# %%
from data_embedding import get_model_and_tokenizer, embed_texts

model, tokenizer = get_model_and_tokenizer()
embeddings = embed_texts(df['Description'].tolist(), model, tokenizer)
embeddings[0][:5]  # First 5 dimensions of the first embedding
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from data_embedding import get_model_and_tokenizer, embed_texts
#       3 model, tokenizer = get_model_and_tokenizer()
#       4 embeddings = embed_texts(df['Description'].tolist(), model, tokenizer)
#
# File c:\Users\harne\Desktop\projects\rl4search\src\data\data_embedding.py:1
# ----> 1 from src.config.embedder import EMBEDDER_MODEL_NAME
#       2 from sentence_transformers import SentenceTransformer
#       3 from src.database.faiss_interface import add_embeddings_to_index
#
# ModuleNotFoundError: No module named 'src'
